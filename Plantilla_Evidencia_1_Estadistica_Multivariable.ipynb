# %% [markdown]
# <a href="https://colab.research.google.com/github/HesusG/A1-Introduccion-a-Bases-de-Datos-Santander2021/blob/main/Plantilla_Evidencia_1_Estadistica_Multivariable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Proyecto: Análisis de Eficiencia en Telecomunicaciones***

# %% [markdown]
# # **EQUIPO 2**
# *Max Vidal Moreira*
#
# *José Rigoberto Gabriel Benitez*
#
# *Sarahí Gómez Montiel*
#
# *Bruno Chávez Meza*
#
# [En esta seccion describeremo la posicion de cada
# - Analista de Datos: Se encarga de la operacion general
# - Ingenierio de Datos:  Carga y Limpieza de datos, agregar elementos al github
# - Project Manager: Revision general y subr a canvas. Conclusiones finales
# - DataViz: Rebisar todas las graficas conclusiones intermedias.
#
#
#
# ]
#
# **"FECHA DE ENTREGA"**
# 14 de Noviembre

# %% [markdown]
# # Tabla de Contenido
# - Objetivo del proyecto
# - Carga de Datos
# - Preprocesamiento: Nulos, Outliers, tipo de dato.
# - EDA
# - Plan de Trabajo

# %% [markdown]
# #***Objetivo del Proyecto***

# %% [markdown]
# # Descripcion General
# CallMeMaybe nos ha entregado informacion para analizar informacion sobre los operadores menos eficaces, esto ayudara a los supervisores para las futuras tomas de decisiones.
#
# Se considera que un **operador es ineficaz si tiene una gran cantidad de llamadas entrantes perdidas (internas y externas) y un tiempo de espera prolongado para las llamadas entrantes.**
#
#  **Además, si se supone que un operador debe realizar** llamadas salientes, un número reducido de ellas también será un signo de ineficacia.**
#
# Sus clientes son organizaciones que necesitan distribuir gran cantidad de llamadas entrantes entre varios operadores, o realizar llamadas salientes a través de sus operadores. Los operadores también pueden realizar llamadas internas para comunicarse entre ellos. Estas llamadas se realizan a través de la red de CallMeMaybe.
#
# Con estas bases comenzaremos el estudio
#
# Comencemos!
#
# # Objetivo Particular
# - Identificar Operadores Ineficaces

# %% [markdown]
# # ***Pre-Procesamiento de Datos***

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.cluster.hierarchy as sch

from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Carga de Datos

# %%
telecom_clients = pd.read_csv('https://raw.githubusercontent.com/HesusG/course-itesm-data-mining/refs/heads/main/telecom_clients_us.csv')
telecom_dataset = pd.read_csv('https://raw.githubusercontent.com/HesusG/course-itesm-data-mining/refs/heads/main/telecom_dataset_us.csv')
display(telecom_clients.head())
display(telecom_dataset.head())
# Out:
#    user_id tariff_plan  date_start
# 0   166713           A  2019-08-15
# 1   166901           A  2019-08-23
# 2   168527           A  2019-10-29
# 3   167097           A  2019-09-01
# 4   168193           A  2019-10-16
#    user_id                       date direction internal  operator_id  \
# 0   166377  2019-08-04 00:00:00+03:00        in    False          NaN
# 1   166377  2019-08-05 00:00:00+03:00       out     True     880022.0
# 2   166377  2019-08-05 00:00:00+03:00       out     True     880020.0
# 3   166377  2019-08-05 00:00:00+03:00       out     True     880020.0
# 4   166377  2019-08-05 00:00:00+03:00       out    False     880022.0
#
#    is_missed_call  calls_count  call_duration  total_call_duration
# 0            True            2              0                    4
# 1            True            3              0                    5
# 2            True            1              0                    1
# ...

# %% [markdown]
# ## Inspeccion de De Tipos de Datos

# %%
telecom_clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      732 non-null    int64
#  1   tariff_plan  732 non-null    object
#  2   date_start   732 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 17.3+ KB

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
#  En esta seccion sera necesario que verifiquemos utilizar el tipo de dato adecuado.
#  tariff plan debra ser categorico
#  date start debera ser fecha
# </div>

# %% [markdown]
# # Inspeccion de Nulos

# %%
telecom_clients.isnull().sum()
# Out:
# user_id        0
# tariff_plan    0
# date_start     0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Deberan utilizar un sistema porcentual para expresar cada variable ausente en su porcentaje no en un numero.
# </div>

# %%
telecom_clients.describe()
#No es muy factible una estadística descriptiva en esta base de datos debido a que la única variable numerica es 'user_id'
# Out:
#              user_id
# count     732.000000
# mean   167431.927596
# std       633.810383
# min    166373.000000
# 25%    166900.750000
# 50%    167432.000000
# 75%    167973.000000
# max    168606.000000

# %% [markdown]
# ## Verificacion de Correciones

# %% [markdown]
# ## Identificar Outliers (variables numericas)
# Una ves sin nulos
# hacer un boxplot y eliminar nulos donde sea conveniente
# ojo con la duracion de llamadas.

# %% [markdown]
# # ***Analisis exploratorio de datos***

# %% [markdown]
# Contamos con dos set de datos:
#
# telecom_dataset_us.csv contiene la información de las llamadas realizadas desde/al callcenter y de los operadores que tomaron/realizaron las llamadas.
#
# telecom_clientes_us.csv contiene la información de los clientes.
#
# El dataset comprimido telecom_dataset_us.csv contiene las siguientes columnas:
#
# user_id: ID de la cuenta de cliente que debe ser unico
#
# date: fecha en la que se recuperaron las estadísticas.Esta corresponde a un formato dd/MM/YYYY HH:mm para su analisis
#
# direction: "dirección" de llamada (out para saliente, in para entrante)
#
# internal: si la llamada fue interna (entre los operadores de un cliente o clienta)
#
# operator_id: identificador del operador
#
# is_missed_call: si fue una llamada perdida
#
# calls_count: número de llamadas
#
# call_duration: duración de la llamada (sin incluir el tiempo de espera)
#
# total_call_duration: duración de la llamada (incluido el tiempo de espera)
#
# El conjunto de datos telecom_clients_us.csv tiene las siguientes columnas:
#
# user_id: ID de usuario/a
#
# tariff_plan: tarifa actual de la clientela
#
# date_start: fecha de registro de la clientela

# %% [markdown]
# # Variables Numericas

# %% [markdown]
# - Dispersion
#   Hexbin
# - Histograma
# - Boxplot

# %% [markdown]
# # Variables Categoricas

# %% [markdown]
# - Diagrama de Pay
# - Diagrama barras

# %% [markdown]
# # Identificacion de Operadores Ineficaces

# %% [markdown]
# # Llamadas Entrantes

# %% [markdown]
# Solo los operadores con gran cantidad de llamadas internas y externas
# Ir agregando a una lista.

# %% [markdown]
# # Tiempo de Espera

# %% [markdown]
# Hacer una nueva columna llamada tiempo de espera y contar los operadores con altos de espera. Finalmente agregarlos a la lista.

# %% [markdown]
# # LLamadas Salientes.
# Contar operadores con pocas llamadas salientes.
# Utlizar groupby y count

# %% [markdown]
# # Plan de Trabajo
#
# Escribir conclusiones apartir de los datos.
# Describir patrones de los operadores ineficaces.
# Proponer una tecnica de mineria de datos a utlizzar en la evidencia 2.
# - Regresion Lineal
# - Regresion Logistica
# - Clustering
# - Clasificadores
# - Pruebas de hipotesis.
#
# Describen con que variables van a operar y si hace falta procesar los datos nuavamente para funcionar en la tecnica
